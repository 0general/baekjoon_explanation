# %% [markdown]
# # [상자넣기](https://www.acmicpc.net/problem/1965)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 가장 긴 증가하는 부분 수열의 유형과 동일한 문제이므로 그림 없음
#
#
# [DP로 푸는 방법 = 가장 긴 증가하는 부분 수열](https://github.com/0general/baekjoon_explanation/blob/main/DP-%EB%8B%A4%EC%9D%B4%EB%82%98%EB%AF%B9%20%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D/11053%20%EA%B0%80%EC%9E%A5%20%EA%B8%B4%20%EC%A6%9D%EA%B0%80%ED%95%98%EB%8A%94%20%EB%B6%80%EB%B6%84%20%EC%88%98%EC%97%B4.ipynb)
# [DP = 가장 긴 감소하는 부분 수열](https://github.com/0general/baekjoon_explanation/blob/main/DP-%EB%8B%A4%EC%9D%B4%EB%82%98%EB%AF%B9%20%ED%94%84%EB%A1%9C%EA%B7%B8%EB%9E%98%EB%B0%8D/11722%20%EA%B0%80%EC%9E%A5%20%EA%B8%B4%20%EA%B0%90%EC%86%8C%ED%95%98%EB%8A%94%20%EB%B6%80%EB%B6%84%20%EC%88%98%EC%97%B4.ipynb)
# [이분탐색으로 푸는 방법 = 전깃줄](https://github.com/0general/baekjoon_explanation/blob/main/Binary%20Search-%EC%9D%B4%EB%B6%84%ED%83%90%EC%83%89/2565%20%EC%A0%84%EA%B9%83%EC%A4%84.ipynb)

# %%
import sys

input = sys.stdin.readline

n = int(input())
arr = []
nums = list(map(int, input().rstrip().split()))

for num in nums:
    if len(arr) == 0:
        arr.append(num)
    else:
        if arr[-1] < num:
            arr.append(num)
            continue
        if arr[-1] > num:
            s, e = 0, len(arr)-1
            ans = 0
            while s <= e:
                mid = (s+e)//2
                if arr[mid] >= num:
                    ans = mid
                    e = mid - 1
                else:
                    s = mid + 1
            arr[ans] = num

print(len(arr))
