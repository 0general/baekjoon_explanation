# %% [markdown]
# # [토마토](https://www.acmicpc.net/problem/7569)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # [7576 토마토 문제](https://github.com/0general/baekjoon_explanation/blob/main/DFS%26BFS/7576%20%ED%86%A0%EB%A7%88%ED%86%A0.ipynb)와 다르지 않다.
# # 그냥 이동 방향이 위, 아래로 2개 더 추가됐을 뿐

# %% [markdown]
# <!-- ![](./image/7569.png) -->
# ![image.png](attachment:image.png)

# %%
import sys
from collections import deque

# %%
def bfs(zero_num):
    dx = [0, 0, 0, 1, 0, -1]
    dy = [0, 0, 1, 0, -1, 0]
    dz = [1, -1, 0, 0, 0, 0]
    while q:
        h, n, m, cnt = q.popleft()
        for i in range(len(dx)):
            z, x, y = h+dz[i], n+dx[i], m+dy[i]
            if 0 <= z < H and 0 <= x < N and 0 <= y < M and not visited[z][x][y] and graph[z][x][y] == 0:
                visited[z][x][y] = True
                zero_num -= 1  # 익지 않은 토마토 수 줄이기
                if zero_num == 0: # 토마토가 모두 익었다면
                    return cnt + 1
                q.append((z, x, y, cnt+1))
    if zero_num: # 익지 않은 토마토가 남아있다면
        return -1

# %%
input = sys.stdin.readline
q = deque()

M, N, H = map(int, input().split())
visited = [[[False]*M for _ in range(N)] for _ in range(H)]
graph = []
zero_num = 0

# %%
for h in range(H):
    arr = []
    for n in range(N): # 입력을 받으면서 토마토 상태 미리 탐색
        l = list(map(int, input().rstrip().split()))
        for m in range(M):
            if l[m] == 1:  # 이미 익어있는 토마토면
                visited[h][n][m] = True
                q.append((h, n, m, 0))
            elif l[m] == 0:  # 익어야 하는 토마토의 개수 = 익지 않은 토마토의 개수
                zero_num += 1
        arr.append(l)
    graph.append(arr)

if zero_num == 0:
    print(0)
else:
    print(bfs(zero_num))
